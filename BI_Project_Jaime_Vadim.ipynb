# %% [markdown]
# <a href="https://colab.research.google.com/github/david1497/NYC-Airbnb-project/blob/master/BI_Project_Jaime_Vadim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geopandas

# %%
'''Importing Data Manipulation Modules'''
import numpy as np                 # Linear Algebra
import pandas as pd                # Data Processing, CSV file I/O (e.g. pd.read_csv)

'''Seaborn and Matplotlib Visualization'''
import matplotlib                  # 2D Plotting Library
import matplotlib.pyplot as plt
import seaborn as sns              # Python Data Visualization Library based on matplotlib
import geopandas as gpd            # Python Geospatial Data Library
plt.style.use('fivethirtyeight')
# %matplotlib inline

'''Plotly Visualizations'''
import plotly as plotly                # Interactive Graphing Library for Python
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot, plot
init_notebook_mode(connected=True)

'''Spatial Visualizations'''
import folium
import folium.plugins

'''NLP - WordCloud'''
import wordcloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

'''Machine Learning'''
import sklearn
from sklearn import preprocessing
from sklearn import metrics
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('https://drive.google.com/file/d/1ux_ng3Y5AKPeLeDoU1pr4tBQS67U7SDm/view?usp=sharing')

# %%
df.head()
# Out:
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
#
# [5 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
pd.options.display.float_format = '{:.2f}'.format
df.describe()
# Out:
#                id  ...  availability_365
# count    48895.00  ...          48895.00
# mean  19017143.24  ...            112.78
# std   10983108.39  ...            131.62
# min       2539.00  ...              0.00
# 25%    9471945.00  ...              0.00
# 50%   19677284.00  ...             45.00
# 75%   29152178.50  ...            227.00
# max   36487245.00  ...            365.00
#
# [8 rows x 10 columns]

# %% [markdown]
# ## Study Outliers

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(df.price, df.minimum_nights)

# %%
'''df[df['minimum_nights']==1250]
class_mapping = {5767:7}
df['minimum_nights'] =  df['minimum_nights'].map(class_mapping)'''
# Out:
#            id  ... availability_365
# 5767  4204302  ...              365
#
# [1 rows x 16 columns]

# %% [markdown]
# ## Check missing data

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# # Prepare the data
# ***
# 1. Impute missing data
# 2. Feature encoding
# 3. Create features `nºdays * minimum nights`
# 4. Convert to categorical
#
#
# ***

# %% [markdown]
# ### 1. Impute Missing Data

# %%
df[["name", "host_name"]] = df[["name", "host_name"]].fillna("missing")

# %%
df.isna().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# ### 2. Feature encoding

# %%
dummies = pd.get_dummies(df[["neighbourhood", "neighbourhood_group", "room_type"]])

# %%
df_dummies = pd.concat([df.drop(["neighbourhood", "neighbourhood_group", "room_type"], axis=1), dummies], axis=1)

# %%
df_dummies.head()
# Out:
#      id  ... room_type_Shared room
# 0  2539  ...                     0
# 1  2595  ...                     0
# 2  3647  ...                     0
# 3  3831  ...                     0
# 4  5022  ...                     0
#
# [5 rows x 242 columns]

# %% [markdown]
# ### 3. Create new features `min_nights_rev`

# %%
df['min_nights_rev'] = df['minimum_nights'] * df['number_of_reviews']

# %%
df['min_nights_rev'].describe()
# Out:
# count   48895.00
# mean       90.41
# std       544.37
# min         0.00
# 25%         2.00
# 50%        16.00
# 75%        70.00
# max     62800.00
# Name: min_nights_rev, dtype: float64

# %% [markdown]
# ### 4. Convert to categorical

# %% [markdown]
# `min_night_rev`

# %%
df.loc[ df['min_night_rev'] == 0, 'number_of_reviews_categories'] = 0
df.loc[(df['number_of_reviews'] > 0) & (df['number_of_reviews'] <= 5), 'number_of_reviews_categories'] = "0-5"
df.loc[(df['number_of_reviews'] > 5) & (df['number_of_reviews'] <= 10), 'number_of_reviews_categories'] = "5-10"
df.loc[(df['number_of_reviews'] > 10) & (df['number_of_reviews'] <= 20), 'number_of_reviews_categories'] = "10-20"
df.loc[(df['number_of_reviews'] > 20) & (df['number_of_reviews'] <= 50), 'number_of_reviews_categories'] = "20-50"

# %% [markdown]
# `number of reviews`

# %%
df['number_of_reviews'] = df['number_of_reviews'].astype(int)
df.loc[ df['number_of_reviews'] == 0, 'number_of_reviews'] = 0
df.loc[(df['number_of_reviews'] > 0) & (df['number_of_reviews'] <= 5), 'number_of_reviews'] = 1
df.loc[(df['number_of_reviews'] > 5) & (df['number_of_reviews'] <= 10), 'number_of_reviews'] = 2
df.loc[(df['number_of_reviews'] > 10) & (df['number_of_reviews'] <= 20), 'number_of_reviews'] = 3
df.loc[(df['number_of_reviews'] > 20) & (df['number_of_reviews'] <= 50), 'number_of_reviews'] = 4
df.loc[(df['number_of_reviews'] > 50) & (df['number_of_reviews'] <= 100), 'number_of_reviews'] = 5
df.loc[df['number_of_reviews'] > 100, 'number_of_reviews'] = 6

# let's see how it's distributed 
df['number_of_reviews'].value_counts()
# Out:
# 1    14841
# 0    10052
# 4     6290
# 2     5430
# 3     5323
# 5     3964
# 6     2995
# Name: number_of_reviews, dtype: int64

# %%
# Making the plot understandable
df.loc[ df['number_of_reviews'] == 0, 'number_of_reviews_categories'] = 0
df.loc[(df['number_of_reviews'] > 0) & (df['number_of_reviews'] <= 5), 'number_of_reviews_categories'] = "0-5"
df.loc[(df['number_of_reviews'] > 5) & (df['number_of_reviews'] <= 10), 'number_of_reviews_categories'] = "5-10"
df.loc[(df['number_of_reviews'] > 10) & (df['number_of_reviews'] <= 20), 'number_of_reviews_categories'] = "10-20"
df.loc[(df['number_of_reviews'] > 20) & (df['number_of_reviews'] <= 50), 'number_of_reviews_categories'] = "20-50"
df.loc[(df['number_of_reviews'] > 50) & (df['number_of_reviews'] <= 100), 'number_of_reviews_categories'] = "50-100"
df.loc[df['number_of_reviews'] > 100, 'number_of_reviews_categories'] = ">100"

# %% [markdown]
# # EDA

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col1 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col2 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col3 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col4 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col5 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col6 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col7 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col8 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row0_col9 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col0 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col2 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col3 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col5 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col6 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col7 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col8 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row1_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col1 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col5 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col6 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col8 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col0 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col1 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col2 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col5 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col6 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col7 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row3_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col0 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col1 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col2 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col5 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col6 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col7 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col8 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row4_col9 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col0 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col1 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col2 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col4 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col6 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col8 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_1becfce0_bf05_11ea_b694_0242ac1c0002row5_col9 {
#             background-color:  #6b8df0;
#             color:  #000000;

# %%
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['neighbourhood_group'].value_counts().plot.pie(explode=[0,0.05,0,0,0],autopct='%1.1f%%',ax=ax[0],shadow=False)
ax[0].set_title('Share of Neighborhood')
ax[0].set_ylabel('Neighborhood Share')
sns.countplot('neighbourhood_group',data=df,ax=ax[1],order=df['neighbourhood_group'].value_counts().index)
ax[1].set_title('Share of Neighborhood')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plt.ioff()

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['number_of_reviews_categories'].value_counts().plot.pie(autopct='%1.1f%%',ax=ax[0],shadow=False)
ax[0].set_title('Number of reviews')
ax[0].set_ylabel('Number of Reviews')
sns.countplot('number_of_reviews_categories',order=df['number_of_reviews_categories'].value_counts().index, data=df,ax=ax[1])
ax[1].set_title('Number of reviews')
plt.show()
